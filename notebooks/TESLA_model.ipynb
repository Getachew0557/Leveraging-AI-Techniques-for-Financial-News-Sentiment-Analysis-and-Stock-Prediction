# %%
# Import necessary modules and functions
import pandas as pd
import sys
import pandas as pd
import matplotlib.pyplot as plt
import os
sys.path.append('../scripts')
import Preprocessing as dp

# %%
#load Dataset
df = pd.read_csv("../data/TESLA_historical_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #load Dataset
# ----> 2 df = pd.read_csv("../data/TESLA_historical_data.csv")
#       3 df.head()
#
# ...

# %%
df.shape
# Out:
# (2926, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2926 entries, 0 to 2925
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2926 non-null   object
#  1   Open          2926 non-null   float64
#  2   High          2926 non-null   float64
#  3   Low           2926 non-null   float64
#  4   Close         2926 non-null   float64
#  5   Adj Close     2926 non-null   float64
#  6   Volume        2926 non-null   int64
#  7   Dividends     2926 non-null   float64
#  8   Stock Splits  2926 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 205.9+ KB

# %%
df.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Adj Close       float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
df.value_counts()
# Out:
# Date        Open        High        Low         Close       Adj Close   Volume    Dividends  Stock Splits
# 2012-12-12  28.000000   28.139999   27.370001   27.580000   27.523441   46704200  0.0        0.0             1
# 2020-09-01  294.709991  301.489990  292.709991  295.440002  294.834137  17295900  0.0        0.0             1
# 2020-09-03  295.989990  297.600006  283.630005  291.119995  290.522980  32294100  0.0        0.0             1
# 2020-09-04  287.250000  289.000000  271.140015  282.730011  282.150208  30333700  0.0        0.0             1
# 2020-09-08  271.279999  279.299988  269.420013  271.160004  270.603943  24864000  0.0        0.0             1
#                                                                                                             ..
# 2016-10-28  130.500000  132.970001  129.929993  131.289993  131.020767  24545500  0.0        0.0             1
# ...

# %%
# Calculate summary statistics
dp.summary_statistics(df)
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2926.000000  2926.000000  2926.000000  2926.000000  2926.000000
# mean    179.557215   181.875331   177.317761   179.649453   179.305921
# std     108.864895   110.256219   107.511134   108.906971   108.755055
# min      22.990000    23.090000    22.670000    22.900000    22.853037
# 25%      97.767502    98.772499    95.889997    97.382498    97.182795
# 50%     166.870003   168.850006   164.210007   166.855003   166.512825
# 75%     231.450005   234.934998   228.687504   232.424999   231.948360
# max     542.349976   542.809998   528.359985   539.909973   539.909973
#
#              Volume    Dividends  Stock Splits
# count  2.926000e+03  2926.000000        2926.0
# mean   2.872083e+07     0.000342           0.0
# std    2.269811e+07     0.013070           0.0
# min    5.467500e+06     0.000000           0.0
# 25%    1.571308e+07     0.000000           0.0
# ...

# %%
# Check for missing values
dp.check_missing_values(df)
# Out:
# Missing Values:
#  Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
# Convert 'Date' column to datetime and set it as index
df = dp.convert_date(df)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441  46704200
# 2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087  81051600
# 2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020  91631600
# 2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143  57742500
# 2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173  60512900
#
#             Dividends  Stock Splits
# Date
# 2012-12-12        0.0           0.0
# 2012-12-13        0.0           0.0
# 2012-12-14        0.0           0.0
# 2012-12-17        0.0           0.0
# 2012-12-18        0.0           0.0

# %%
# Calculate technical indicators
df = dp.calculate_technical_indicators(df)
df.head(60)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441   46704200
# 2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087   81051600
# 2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020   91631600
# 2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143   57742500
# 2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173   60512900
# 2012-12-19  27.830000  28.219999  26.950001  27.410000  27.353790   61390300
# 2012-12-20  27.490000  27.600000  27.129999  27.360001  27.303892   35574800
# 2012-12-21  26.660000  27.010000  26.120001  26.260000  26.206148   54555200
# 2012-12-24  26.500000  26.959999  26.200001  26.930000  26.874775   28230100
# 2012-12-26  27.030001  27.180000  26.379999  26.510000  26.455635   33175400
# 2012-12-27  26.549999  26.799999  25.520000  26.049999  25.996578   43481700
# ...

# %%
# Plot stock data with Moving Averages
dp.plot_stock_data(df)

# %%
# Plot Relative Strength Index (RSI)
dp.plot_rsi(df)

# %%
# Plot Moving Average Convergence Divergence (MACD)
dp.plot_macd(df)

# %%
# Fetch historical stock data using yfinance
historical_data = dp.fetch_stock_data('TESLA')
historical_data['Close'].plot(title='TESLA Closing Prices')
plt.show()
# Out:
# $TESLA: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")

# %%
# Calculate and print financial metrics
ticker = 'TESLA'
metrics = dp.financial_metrics(ticker)
print("Financial Metrics:\n", metrics)
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TESLA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TESLA&crumb=MHZSYW2sEc%2F
# Financial Metrics:
#  {'PE_Ratio': 'N/A', 'Market_Cap': 'N/A', 'Dividend_Yield': 'N/A'}
